# %% [markdown]
# IMPORTING ALL NECESSARY PACKAGES. MOST OF THEM ARE ALREADY IN THE ANACONDA DISTRIBUTION

# %%
import requests
from bs4 import BeautifulSoup as soup
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %%
url ='https://understat.com/match/30224'

# %%
html = requests.get(url)

# %%
html.content
# Out:
# b'<!DOCTYPE html>\n<html>\n    <head>\n\t\t<base href="https://understat.com/">\n\t\t<title>Bayern Munich 6 - 0 RasenBallsport Leipzig (August 22 2025) | Bundesliga | 2025/2026 | xG | Understat.com</title>\n        <meta charset="UTF-8" />\n\t\t<meta name="description" content="Bayern Munich 6 - 0 RasenBallsport Leipzig. Check out detailed player statistic, goals, assists, key passes, xG, shot map, xGplot.">\n\t\t<meta name="Keywords" content="Bayern Munich, RasenBallsport Leipzig, Bundesliga, 2025/2026, (August 22 2025), xG, expected goals, shot map"> \n\t\t\t<link rel="apple-touch-icon" sizes="180x180" href="apple-touch-icon.png">\n\t<link rel="icon" type="image/png" sizes="32x32" href="favicon-32x32.png">\n\t<link rel="icon" type="image/png" sizes="16x16" href="favicon-16x16.png">\n\t<link rel="manifest" href="manifest.json">\n\t<link rel="mask-icon" href="safari-pinned-tab.svg" color="#5bbad5">\n\t<meta name="apple-mobile-web-app-title" content="understat">\n\t<meta name="application-name" content="understat">\n\t<meta name="theme-color" content="#ffffff">\n\t<meta http-equiv="cache-control" content="no-cache">\n\t<meta http-equiv="expires" content="0">\n\t<link href="css/main.css?v=2.8" rel="stylesheet" media="screen">\n    </head>\n    <body class="theme-dark">\n\t\t<script>\n\t\t\tvar THEME = localStorage.getItem("theme") || \'DARK\';\n\t\t\tdocument.body.className = "theme-" + THEME.toLowerCase();\n\t\t</script>\n        \t<div class="wrapper">\n\t\t<header id="header" class="clearfix">\n\t\t\t<div class="header-wrapper">\n\t\t\t\t\t<span class="block-match-result">\n\t\t<a href="https://understat.com/team/Bayern_Munich/2025">Bayern Munich</a> 6 - 0<a href="https://understat.com/team/RasenBallsport_Leipzig/2025">RasenBallsport Leipzig</a>\n\t</span>\n\t\t\t\t<nav class="m-navigation-main">\n\t\t\t\t\t<ul class="h-inner">\n\t\t\t\t\t\t<li class="player-search">\n\t\t\t\t\t\t\t<input class="typeahead" type="search" placeholder="Find player by name" />\n\t\t\t\t\t\t\t<span class="icon"><i class="fa fa-search"></i></span>\n\t\t\t\t\t\t</li>\n\t\t\t\t\t\t<li>\n\t\t\t\t\t\t\t<a class="link-icon" href="" title="Main page">\n\t\t\t\t\t\t\t\t<i class="fas fa-home" aria-hidden="true"></i>\n\t\t\t\t\t\t\t</a>\n\t\t\t\t\t\t</li>\n\t\t\t\t\t\t<li>\n\t\t\t\t\t\t\t<a class="link-icon" href="office" title="Personal cabinet">\n\t\t\t\t\t\t\t\t<i class="fas fa-sign-in-alt" aria-hidden="true"></i>\n\t\t\t\t\t\t\t</a>\n\t\t\t\t\t\t</li>\n\t\t\t\t\t</ul>\n\t\t\t\t</nav>\n\t\t\t</div>\n\t\t</header>\n\t\t\n\t\t<div class="preloader">\n\t\t\t<div class="preloader-container">\n\t\t\t\t<div class="circ1"><div></div></div>\n\t\t\t\t<div class="circ2"><div></div></div>\n\t\t\t\t<div class="circ3"><div></div></div>\n\t\t\t\t<div class="circ4"><div></div></div>\n\t\t\t</div>\n\t\t</div>\n\t\t\n\t\t<div id="table-preloader" class="preloader table-preloader is-hide">\n\t\t\t<div class="preloader-container">\n\t\t\t\t<div class="circ1"><div></div></div>\n\t\t\t\t<div class="circ2"><div></div></div>\n\t\t\t\t<div class="circ3"><div></div></div>\n\t\t\t\t<div class="circ4"><div></div></div>\n\t\t\t</div>\n\t\t</div>\n\t\t\n\t\t<input id="themes-switch" type="checkbox" name="themes-switch" checked>\n\t\t<label for="themes-switch" title="Change theme"></label>\n\t\t\n\t\t<div class="page-wrapper">\n\t\t\t\t\t\t\t\t\t\t<div class="promotion">\n\t\t\t\t<ins class="adsbygoogle" style="display:block" data-ad-client="ca-pub-7470116180195095" data-ad-slot="2199699885" data-ad-format="auto" data-full-width-responsive="true"></ins>\n\t\t\t</div>\n\t\t\t\t\t\t\t\t\t\t<ul class="breadcrumb">\n\t<li><a href="https://understat.com/">Home</a></li>\n\t<li><a href="league/Bundesliga/2025">Bundesliga</a></li>\n\t<li>Aug 22 2025</li>\n</ul>\n\t\t\t<div class="block">\n\t<div class="block-content">\n\t\t<div class="block-match">\n\t\t\t<div class="filters">\n\t<div class="filter">\n\t\t<input id="scheme1" type="radio" name="scheme" value="field" checked />\n\t\t<label for ...

# %%
parse_soup = soup(html.content,'lxml')

# %%
scripts = parse_soup.find_all('script')
len(scripts)
# Out:
# 23

# %% [markdown]
# A QUICK GLANCE AND WE FIND THE NECESSARY DATA(SHOTSDATA) IS INDEX 3. SO WE EXTRACT FROM THAT DICTIONARY.

# %%
scripts[1].string
# Out:
# "\n\tvar shotsData \t= JSON.parse('\\x7B\\x22h\\x22\\x3A\\x5B\\x7B\\x22id\\x22\\x3A\\x22638513\\x22,\\x22minute\\x22\\x3A\\x223\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.9409999847412109\\x22,\\x22Y\\x22\\x3A\\x220.24700000762939453\\x22,\\x22xG\\x22\\x3A\\x220.05909460783004761\\x22,\\x22player\\x22\\x3A\\x22Michael\\x20Olise\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x229948\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222025\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2230224\\x22,\\x22h_team\\x22\\x3A\\x22Bayern\\x20Munich\\x22,\\x22a_team\\x22\\x3A\\x22RasenBallsport\\x20Leipzig\\x22,\\x22h_goals\\x22\\x3A\\x226\\x22,\\x22a_goals\\x22\\x3A\\x220\\x22,\\x22date\\x22\\x3A\\x222025\\x2D08\\x2D22\\x2018\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Serge\\x20Gnabry\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22638514\\x22,\\x22minute\\x22\\x3A\\x2210\\x22,\\x22result\\x22\\x3A\\x22SavedShot\\x22,\\x22X\\x22\\x3A\\x220.899000015258789\\x22,\\x22Y\\x22\\x3A\\x220.29399999618530276\\x22,\\x22xG\\x22\\x3A\\x220.28661295771598816\\x22,\\x22player\\x22\\x3A\\x22Konrad\\x20Laimer\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x226109\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222025\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2230224\\x22,\\x22h_team\\x22\\x3A\\x22Bayern\\x20Munich\\x22,\\x22a_team\\x22\\x3A\\x22RasenBallsport\\x20Leipzig\\x22,\\x22h_goals\\x22\\x3A\\x226\\x22,\\x22a_goals\\x22\\x3A\\x220\\x22,\\x22date\\x22\\x3A\\x222025\\x2D08\\x2D22\\x2018\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Harry\\x20Kane\\x22,\\x22lastAction\\x22\\x3A\\x22Chipped\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22638515\\x22,\\x22minute\\x22\\x3A\\x2215\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.785\\x22,\\x22Y\\x22\\x3A\\x220.5579999923706055\\x22,\\x22xG\\x22\\x3A\\x220.03585360199213028\\x22,\\x22player\\x22\\x3A\\x22Serge\\x20Gnabry\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x22993\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222025\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2230224\\x22,\\x22h_team\\x22\\x3A\\x22Bayern\\x20Munich\\x22,\\x22a_team\\x22\\x3A\\x22RasenBallsport\\x20Leipzig\\x22,\\x22h_goals\\x22\\x3A\\x226\\x22,\\x22a_goals\\x22\\x3A\\x220\\x22,\\x22date\\x22\\x3A\\x222025\\x2D08\\x2D22\\x2018\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Harry\\x20Kane\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22638516\\x22,\\x22minute\\x22\\x3A\\x2224\\x22,\\x22result\\x22\\x3A\\x22MissedShots\\x22,\\x22X\\x22\\x3A\\x220.8640000152587891\\x22,\\x22Y\\x22\\x3A\\x220.43200000762939456\\x22,\\x22xG\\x22\\x3A\\x220.12117602676153183\\x22,\\x22player\\x22\\x3A\\x22Harry\\x20Kane\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x22647\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222025\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2230224\\x22,\\x22h_team\\x22\\x3A\\x22Bayern\\x20Munich\\x22,\\x22a_team\\x22\\x3A\\x22RasenBallsport\\x20Leipzig\\x22,\\x22h_goals\\x22\\x3A\\x226\\x22,\\x22a_goals\\x22\\x3A\\x220\\x22,\\x22date\\x22\\x3A\\x222025\\x2D08\\x2D22\\x2018\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Joshua\\x20Kimmich\\x22,\\x22lastAction\\x22\\x3A\\x22Throughball\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22638517\\x22,\\x22minute\\x22\\x3A\\x2226\\x22,\\x22result\\x22\\x3A\\x22Goal\\x22,\\x22X\\x22\\x3A\\x220.879000015258789\\x22,\\x22Y\\x22\\x3A\\x220.35400001525878905\\x22,\\x22xG\\x22\\x3A\\x220.06916379928588867\\x22,\\x22player\\x22\\x3A\\x22Michael\\x20Olise\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x229948\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222025\\x ...

# %%
strings = scripts[1].string

# %%
ind_start = strings.index("('")+2
ind_end = strings.index("')")

json_data = strings[ind_start:ind_end]
json_data = json_data.encode('utf8').decode('unicode_escape')

json_data
# Out:
# '{"h":[{"id":"638513","minute":"3","result":"BlockedShot","X":"0.9409999847412109","Y":"0.24700000762939453","xG":"0.05909460783004761","player":"Michael Olise","h_a":"h","player_id":"9948","situation":"OpenPlay","season":"2025","shotType":"RightFoot","match_id":"30224","h_team":"Bayern Munich","a_team":"RasenBallsport Leipzig","h_goals":"6","a_goals":"0","date":"2025-08-22 18:30:00","player_assisted":"Serge Gnabry","lastAction":"Pass"},{"id":"638514","minute":"10","result":"SavedShot","X":"0.899000015258789","Y":"0.29399999618530276","xG":"0.28661295771598816","player":"Konrad Laimer","h_a":"h","player_id":"6109","situation":"OpenPlay","season":"2025","shotType":"RightFoot","match_id":"30224","h_team":"Bayern Munich","a_team":"RasenBallsport Leipzig","h_goals":"6","a_goals":"0","date":"2025-08-22 18:30:00","player_assisted":"Harry Kane","lastAction":"Chipped"},{"id":"638515","minute":"15","result":"BlockedShot","X":"0.785","Y":"0.5579999923706055","xG":"0.03585360199213028","player":"Serge Gnabry","h_a":"h","player_id":"993","situation":"OpenPlay","season":"2025","shotType":"LeftFoot","match_id":"30224","h_team":"Bayern Munich","a_team":"RasenBallsport Leipzig","h_goals":"6","a_goals":"0","date":"2025-08-22 18:30:00","player_assisted":"Harry Kane","lastAction":"Pass"},{"id":"638516","minute":"24","result":"MissedShots","X":"0.8640000152587891","Y":"0.43200000762939456","xG":"0.12117602676153183","player":"Harry Kane","h_a":"h","player_id":"647","situation":"OpenPlay","season":"2025","shotType":"RightFoot","match_id":"30224","h_team":"Bayern Munich","a_team":"RasenBallsport Leipzig","h_goals":"6","a_goals":"0","date":"2025-08-22 18:30:00","player_assisted":"Joshua Kimmich","lastAction":"Throughball"},{"id":"638517","minute":"26","result":"Goal","X":"0.879000015258789","Y":"0.35400001525878905","xG":"0.06916379928588867","player":"Michael Olise","h_a":"h","player_id":"9948","situation":"OpenPlay","season":"2025","shotType":"RightFoot","match_id":"30224","h_team":"Bayern Munich","a_team":"RasenBallsport Leipzig","h_goals":"6","a_goals":"0","date":"2025-08-22 18:30:00","player_assisted":null,"lastAction":"BallTouch"},{"id":"638520","minute":"31","result":"Goal","X":"0.879000015258789","Y":"0.45799999237060546","xG":"0.4198751151561737","player":"Luis D\\u00edaz","h_a":"h","player_id":"10408","situation":"OpenPlay","season":"2025","shotType":"RightFoot","match_id":"30224","h_team":"Bayern Munich","a_team":"RasenBallsport Leipzig","h_goals":"6","a_goals":"0","date":"2025-08-22 18:30:00","player_assisted":"Serge Gnabry","lastAction":"Pass"},{"id":"638521","minute":"35","result":"BlockedShot","X":"0.784000015258789","Y":"0.28700000762939454","xG":"0.058959171175956726","player":"Michael Olise","h_a":"h","player_id":"9948","situation":"DirectFreekick","season":"2025","shotType":"LeftFoot","match_id":"30224","h_team":"Bayern Munich","a_team":"RasenBallsport Leipzig","h_goals":"6","a_goals":"0","date":"2025-08-22 18:30:00","player_assisted":null,"lastAction":"Standard"},{"id":"638522","minute":"35","result":"BlockedShot","X":"0.924000015258789","Y":"0.32799999237060545","xG":"0.05382798612117767","player":"Harry Kane","h_a":"h","player_id":"647","situation":"SetPiece","season":"2025","shotType":"RightFoot","match_id":"30224","h_team":"Bayern Munich","a_team":"RasenBallsport Leipzig","h_goals":"6","a_goals":"0","date":"2025-08-22 18:30:00","player_assisted":null,"lastAction":"Rebound"},{"id":"638523","minute":"39","result":"BlockedShot","X":"0.8340000152587891","Y":"0.5620000076293945","xG":"0.10655874013900757","player":"Serge Gnabry","h_a":"h","player_id":"993","situation":"OpenPlay","season":"2025","shotType":"LeftFoot","match_id":"30224","h_team":"Bayern Munich","a_team":"RasenBallsport Leipzig","h_goals":"6","a_goals":"0","date":"2025-08-22 18:30:00","player_assisted":"Luis D\\u00edaz","lastAction":"LayOff"},{"id":"638524","minute":"41","result":"Goal","X":"0.914000015258789","Y":"0.43","xG":"0.43276408314704895","player":"Michael O ...

# %%
data = json.loads(json_data)
#data

# %%
data['a']
# Out:
# [{'id': '638518',
#   'minute': '28',
#   'result': 'MissedShots',
#   'X': '0.9419999694824219',
#   'Y': '0.6990000152587891',
#   'xG': '0.0502757802605629',
#   'player': 'David Raum',
#   'h_a': 'a',
#   'player_id': '9724',
#   'situation': 'OpenPlay',
#   'season': '2025',
#   'shotType': 'LeftFoot',
#   'match_id': '30224',
#   'h_team': 'Bayern Munich',
#   'a_team': 'RasenBallsport Leipzig',
#   'h_goals': '6',
#   'a_goals': '0',
#   'date': '2025-08-22 18:30:00',
#   'player_assisted': 'Nicolas Seiwald',
#   'lastAction': 'Chipped'},
#  {'id': '638519',
#   'minute': '28',
#   'result': 'BlockedShot',
#   'X': '0.9259999847412109',
#   'Y': '0.3189999961853027',
#   'xG': '0.04674576595425606',
#   'player': 'Loïs Openda',
#   'h_a': 'a',
#   'player_id': '10832',
#   'situation': 'FromCorner',
#   'season': '2025',
#   'shotType': 'RightFoot',
#   'match_id': '30224',
#   'h_team': 'Bayern Munich',
#   'a_team': 'RasenBallsport Leipzig',
#   'h_goals': '6',
#   'a_goals': '0',
#   'date': '2025-08-22 18:30:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '638525',
#   'minute': '43',
#   'result': 'BlockedShot',
#   'X': '0.8619999694824219',
#   'Y': '0.32799999237060545',
#   'xG': '0.054438427090644836',
#   'player': 'Xaver Schlager',
#   'h_a': 'a',
#   'player_id': '7783',
#   'situation': 'OpenPlay',
#   'season': '2025',
#   'shotType': 'RightFoot',
#   'match_id': '30224',
#   'h_team': 'Bayern Munich',
#   'a_team': 'RasenBallsport Leipzig',
#   'h_goals': '6',
#   'a_goals': '0',
#   'date': '2025-08-22 18:30:00',
#   'player_assisted': 'Johan Bakayoko',
#   'lastAction': 'Pass'},
#  {'id': '638528',
#   'minute': '45',
#   'result': 'BlockedShot',
#   'X': '0.8209999847412109',
#   'Y': '0.3129999923706055',
#   'xG': '0.02903265506029129',
#   'player': 'Johan Bakayoko',
#   'h_a': 'a',
#   'player_id': '13850',
#   'situation': 'OpenPlay',
#   'season': '2025',
#   'shotType': 'LeftFoot',
#   'match_id': '30224',
#   'h_team': 'Bayern Munich',
#   'a_team': 'RasenBallsport Leipzig',
#   'h_goals': '6',
#   'a_goals': '0',
#   'date': '2025-08-22 18:30:00',
#   'player_assisted': 'Xaver Schlager',
#   'lastAction': 'Pass'},
#  {'id': '638529',
#   'minute': '45',
#   'result': 'MissedShots',
#   'X': '0.765',
#   'Y': '0.42',
#   'xG': '0.012898026034235954',
#   'player': 'Xaver Schlager',
#   'h_a': 'a',
#   'player_id': '7783',
#   'situation': 'OpenPlay',
#   'season': '2025',
#   'shotType': 'LeftFoot',
#   'match_id': '30224',
#   'h_team': 'Bayern Munich',
#   'a_team': 'RasenBallsport Leipzig',
#   'h_goals': '6',
#   'a_goals': '0',
#   'date': '2025-08-22 18:30:00',
#   'player_assisted': None,
#   'lastAction': 'Rebound'},
#  {'id': '638526',
#   'minute': '49',
#   'result': 'BlockedShot',
#   'X': '0.8959999847412109',
#   'Y': '0.3029999923706055',
#   'xG': '0.051909636706113815',
#   'player': 'Johan Bakayoko',
#   'h_a': 'a',
#   'player_id': '13850',
#   'situation': 'OpenPlay',
#   'season': '2025',
#   'shotType': 'RightFoot',
#   'match_id': '30224',
#   'h_team': 'Bayern Munich',
#   'a_team': 'RasenBallsport Leipzig',
#   'h_goals': '6',
#   'a_goals': '0',
#   'date': '2025-08-22 18:30:00',
#   'player_assisted': 'Loïs Openda',
#   'lastAction': 'Pass'},
#  {'id': '638530',
#   'minute': '57',
#   'result': 'BlockedShot',
#   'X': '0.914000015258789',
#   'Y': '0.5920000076293945',
#   'xG': '0.0999424085021019',
#   'player': 'Nicolas Seiwald',
#   'h_a': 'a',
#   'player_id': '11871',
#   'situation': 'OpenPlay',
#   'season': '2025',
#   'shotType': 'RightFoot',
#   'match_id': '30224',
#   'h_team': 'Bayern Munich',
#   'a_team': 'RasenBallsport Leipzig',
#   'h_goals': '6',
#   'a_goals': '0',
#   'date': '2025-08-22 18:30:00',
#   'player_assisted': 'Xaver Schlager',
#   'lastAction': 'Pass'},
#  {'id': '638531',
#   'minute': '58',
#   'result': 'BlockedShot',
#   'X': '0.855',
#   'Y': '0.3060000038146973',
#   'xG': '0.030169857665896416',
#   'player': 'Bote Baku',
#   'h_a': 'a',
#   'player_id': '6708',
#   'situation': 'OpenPlay',
#   'season': '2025',
#   'shotType': 'LeftFoot',
#   'match_id': '30224',
#   'h_team': 'Bayern Munich',
#   'a_team': 'RasenBallsport Leipzig',
#   'h_goals': '6',
#   'a_goals': '0',
#   'date': '2025-08-22 18:30:00',
#   'player_assisted': None,
#   'lastAction': 'None'},
#  {'id': '638533',
#   'minute': '61',
#   'result': 'MissedShots',
#   'X': '0.8240000152587891',
#   'Y': '0.5029999923706054',
#   'xG': '0.05595800653100014',
#   'player': 'Antonio Nusa',
#   'h_a': 'a',
#   'player_id': '12941',
#   'situation': 'OpenPlay',
#   'season': '2025',
#   'shotType': 'RightFoot',
#   'match_id': '30224',
#   'h_team': 'Bayern Munich',
#   'a_team': 'RasenBallsport Leipzig',
#   'h_goals': '6',
#   'a_goals': '0',
#   'date': '2025-08-22 18:30:00',
#   'player_assisted': 'Rômulo',
#   'lastAction': 'Tackle'},
#  {'id': '638539',
#   'minute': '82',
#   'result': 'SavedShot',
#   'X': '0.805',
#   'Y': '0.2929999923706055',
#   'xG': '0.01900630071759224',
#   'player': 'Christoph Baumgartner',
#   'h_a': 'a',
#   'player_id': '7422',
#   'situation': 'OpenPlay',
#   'season': '2025',
#   'shotType': 'RightFoot',
#   'match_id': '30224',
#   'h_team': 'Bayern Munich',
#   'a_team': 'RasenBallsport Leipzig',
#   'h_goals': '6',
#   'a_goals': '0',
#   'date': '2025-08-22 18:30:00',
#   'player_assisted': 'Bote Baku',
#   'lastAction': 'TakeOn'},
#  {'id': '638542',
#   'minute': '93',
#   'result': 'BlockedShot',
#   'X': '0.8040000152587891',
#   'Y': '0.6630000305175782',
#   'xG': '0.02922726608812809',
#   'player': 'Antonio Nusa',
#   'h_a': 'a',
#   'player_id': '12941',
#   'situation': 'FromCorner',
#   'season': '2025',
#   'shotType': 'RightFoot',
#   'match_id': '30224',
#   'h_team': 'Bayern Munich',
#   'a_team': 'RasenBallsport Leipzig',
#   'h_goals': '6',
#   'a_goals': '0',
#   'date': '2025-08-22 18:30:00',
#   'player_assisted': 'Xavi Simons',
#   'lastAction': 'Pass'},
#  {'id': '638543',
#   'minute': '94',
#   'result': 'MissedShots',
#   'X': '0.924000015258789',
#   'Y': '0.3970000076293945',
#   'xG': '0.04303041473031044',
#   'player': 'Christoph Baumgartner',
#   'h_a': 'a',
#   'player_id': '7422',
#   'situation': 'FromCorner',
#   'season': '2025',
#   'shotType': 'Head',
#   'match_id': '30224',
#   'h_team': 'Bayern Munich',
#   'a_team': 'RasenBallsport Leipzig',
#   'h_goals': '6',
#   'a_goals': '0',
#   'date': '2025-08-22 18:30:00',
#   'player_assisted': 'David Raum',
#   'lastAction': 'Cross'}]

# %%
hteam=data['a'][0]['h_team'].upper()
hteam
# Out:
# 'BAYERN MUNICH'

# %%
ateam=data['a'][0]['a_team'].upper()
ateam
# Out:
# 'RASENBALLSPORT LEIPZIG'

# %%
x = []
y = []
xg = []
result = []
player = []
homeaway = []

for i,_ in enumerate(data['h']):
    for key in data['h'][i]:
        if key=='X':
            x.append(data['h'][i][key])
        if key=='Y':
            y.append(data['h'][i][key])
        if key=='xG':
            xg.append(data['h'][i][key])
        if key=='result':
            result.append(data['h'][i][key])
        if key=='player':
            player.append(data['h'][i][key])
        if key=='h_a':
            homeaway.append(data['h'][i][key])
            
for i,_ in enumerate(data['a']):
    for key in data['a'][i]:
        if key=='X':
            x.append(data['a'][i][key])
        if key=='Y':
            y.append(data['a'][i][key])
        if key=='xG':
            xg.append(data['a'][i][key])
        if key=='result':
            result.append(data['a'][i][key])
        if key=='player':
            player.append(data['a'][i][key])
        if key=='h_a':
            homeaway.append(data['a'][i][key])

# %%
data['a'][3]['result']
# Out:
# 'BlockedShot'

# %%
columns = ['X','Y','xG','Result','Player', 'HomeAway']
df_understat = pd.DataFrame([x, y, xg, result, player, homeaway], index=columns)
df_understat
# Out:
#                            0                    1                    2   \
# X          0.9409999847412109    0.899000015258789                0.785
# Y         0.24700000762939453  0.29399999618530276   0.5579999923706055
# xG        0.05909460783004761  0.28661295771598816  0.03585360199213028
# Result            BlockedShot            SavedShot          BlockedShot
# Player          Michael Olise        Konrad Laimer         Serge Gnabry
# HomeAway                    h                    h                    h
#
#                            3                    4                    5   \
# X          0.8640000152587891    0.879000015258789    0.879000015258789
# Y         0.43200000762939456  0.35400001525878905  0.45799999237060546
# xG        0.12117602676153183  0.06916379928588867   0.4198751151561737
# Result            MissedShots                 Goal                 Goal
# Player             Harry Kane        Michael Olise            Luis Díaz
# HomeAway                    h                    h                    h
#
#                             6                    7                    8   \
# X            0.784000015258789    0.924000015258789   0.8340000152587891
# Y          0.28700000762939454  0.32799999237060545   0.5620000076293945
# xG        0.058959171175956726  0.05382798612117767  0.10655874013900757
# Result             BlockedShot          BlockedShot          BlockedShot
# Player           Michael Olise           Harry Kane         Serge Gnabry
# HomeAway                     h                    h                    h
#
#                            9   ...                    21                   22  \
# X           0.914000015258789  ...    0.8619999694824219   0.8209999847412109
# Y                        0.43  ...   0.32799999237060545   0.3129999923706055
# xG        0.43276408314704895  ...  0.054438427090644836  0.02903265506029129
# Result                   Goal  ...           BlockedShot          BlockedShot
# Player          Michael Olise  ...        Xaver Schlager       Johan Bakayoko
# HomeAway                    h  ...                     a                    a
#
#                             23                    24                  25  \
# X                        0.765    0.8959999847412109   0.914000015258789
# Y                         0.42    0.3029999923706055  0.5920000076293945
# xG        0.012898026034235954  0.051909636706113815  0.0999424085021019
# Result             MissedShots           BlockedShot         BlockedShot
# Player          Xaver Schlager        Johan Bakayoko     Nicolas Seiwald
# HomeAway                     a                     a                   a
#
#                             26                   27                     28  \
# X                        0.855   0.8240000152587891                  0.805
# Y           0.3060000038146973   0.5029999923706054     0.2929999923706055
# xG        0.030169857665896416  0.05595800653100014    0.01900630071759224
# Result             BlockedShot          MissedShots              SavedShot
# Player               Bote Baku         Antonio Nusa  Christoph Baumgartner
# HomeAway                     a                    a                      a
#
#                            29                     30
# X          0.8040000152587891      0.924000015258789
# Y          0.6630000305175782     0.3970000076293945
# xG        0.02922726608812809    0.04303041473031044
# Result            BlockedShot            MissedShots
# Player           Antonio Nusa  Christoph Baumgartner
# HomeAway                    a                      a
#
# [6 rows x 31 columns]

# %%
df_understat = df_understat.T
df_understat = df_understat.apply(pd.to_numeric,errors='ignore')
df_understat
# Out:
# C:\Users\enado\AppData\Local\Temp\ipykernel_23236\3705794037.py:2: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df_understat = df_understat.apply(pd.to_numeric,errors='ignore')
#         X      Y        xG       Result                 Player HomeAway
# 0   0.941  0.247  0.059095  BlockedShot          Michael Olise        h
# 1   0.899  0.294  0.286613    SavedShot          Konrad Laimer        h
# 2   0.785  0.558  0.035854  BlockedShot           Serge Gnabry        h
# 3   0.864  0.432  0.121176  MissedShots             Harry Kane        h
# 4   0.879  0.354  0.069164         Goal          Michael Olise        h
# 5   0.879  0.458  0.419875         Goal              Luis Díaz        h
# 6   0.784  0.287  0.058959  BlockedShot          Michael Olise        h
# 7   0.924  0.328  0.053828  BlockedShot             Harry Kane        h
# 8   0.834  0.562  0.106559  BlockedShot           Serge Gnabry        h
# 9   0.914  0.430  0.432764         Goal          Michael Olise        h
# 10  0.936  0.579  0.082984  MissedShots          Leon Goretzka        h
# 11  0.757  0.399  0.038399  MissedShots          Michael Olise        h
# 12  0.955  0.587  0.679810         Goal             Harry Kane        h
# 13  0.850  0.719  0.052735         Goal             Harry Kane        h
# 14  0.926  0.627  0.328854         Goal             Harry Kane        h
# 15  0.760  0.403  0.034764    SavedShot           Lennart Karl        h
# 16  0.800  0.203  0.017179  MissedShots         Joshua Kimmich        h
# 17  0.810  0.251  0.044700  BlockedShot           Lennart Karl        h
# 18  0.945  0.321  0.378717    SavedShot           Lennart Karl        h
# 19  0.942  0.699  0.050276  MissedShots             David Raum        a
# 20  0.926  0.319  0.046746  BlockedShot            Loïs Openda        a
# 21  0.862  0.328  0.054438  BlockedShot         Xaver Schlager        a
# 22  0.821  0.313  0.029033  BlockedShot         Johan Bakayoko        a
# 23  0.765  0.420  0.012898  MissedShots         Xaver Schlager        a
# 24  0.896  0.303  0.051910  BlockedShot         Johan Bakayoko        a
# 25  0.914  0.592  0.099942  BlockedShot        Nicolas Seiwald        a
# 26  0.855  0.306  0.030170  BlockedShot              Bote Baku        a
# 27  0.824  0.503  0.055958  MissedShots           Antonio Nusa        a
# 28  0.805  0.293  0.019006    SavedShot  Christoph Baumgartner        a
# 29  0.804  0.663  0.029227  BlockedShot           Antonio Nusa        a
# 30  0.924  0.397  0.043030  MissedShots  Christoph Baumgartner        a

# %%
df_understat[df_understat['Result']=='OwnGoal']
# Out:
# Empty DataFrame
# Columns: [X, Y, xG, Result, Player, HomeAway]
# Index: []

# %%
# THE X AND Y LABELS ARE SCALED BETWEEN 0 and 1. SINCE WE WILL BE USING OPTA AXES WHICH GO FROM 100 to 100, WE NEED TO
# SCALE BOTH THESE UPTO 100

df_understat['X'] = df_understat['X'].apply(lambda x:x*100)
df_understat['Y'] = df_understat['Y'].apply(lambda x:x*100)

df_understat['Result'].unique()
# Out:
# array(['BlockedShot', 'SavedShot', 'MissedShots', 'Goal'], dtype=object)

# %%
df_h=df_understat[df_understat['HomeAway']=='h']
df_h.head()
# Out:
#            X          Y        xG       Result         Player HomeAway
# 0  94.099998  24.700001  0.059095  BlockedShot  Michael Olise        h
# 1  89.900002  29.400000  0.286613    SavedShot  Konrad Laimer        h
# 2  78.500000  55.799999  0.035854  BlockedShot   Serge Gnabry        h
# 3  86.400002  43.200001  0.121176  MissedShots     Harry Kane        h
# 4  87.900002  35.400002  0.069164         Goal  Michael Olise        h

# %%
df_a=df_understat[df_understat['HomeAway']=='a']
df_a.head()
# Out:
#             X          Y        xG       Result          Player HomeAway
# 19  94.199997  69.900002  0.050276  MissedShots      David Raum        a
# 20  92.599998  31.900000  0.046746  BlockedShot     Loïs Openda        a
# 21  86.199997  32.799999  0.054438  BlockedShot  Xaver Schlager        a
# 22  82.099998  31.299999  0.029033  BlockedShot  Johan Bakayoko        a
# 23  76.500000  42.000000  0.012898  MissedShots  Xaver Schlager        a

# %%
df_h.head()
# Out:
#            X          Y        xG       Result         Player HomeAway
# 0  94.099998  24.700001  0.059095  BlockedShot  Michael Olise        h
# 1  89.900002  29.400000  0.286613    SavedShot  Konrad Laimer        h
# 2  78.500000  55.799999  0.035854  BlockedShot   Serge Gnabry        h
# 3  86.400002  43.200001  0.121176  MissedShots     Harry Kane        h
# 4  87.900002  35.400002  0.069164         Goal  Michael Olise        h

# %%
#def ownGoalsH():
rowH=pd.DataFrame(df_h[df_h['Result']=='OwnGoal'])
rowA=pd.DataFrame(df_a[df_a['Result']=='OwnGoal'])

if len(rowH) > 0:
    rowH['X']=100-rowH['X']
    rowH['Y']=100-rowH['Y']
    rowH['xG']=0.05
    df_h=df_h[df_h['Result']!='OwnGoal']
    rowH['Result']='Goal'
    
    
if len(rowA)> 0:
    rowA['X']=100-rowA['X']
    rowA['Y']=100-rowA['Y']
    rowA['xG']=0.05
    df_a=df_a[df_a['Result']!='OwnGoal']
    rowA['Result']= 'Goal'



#print(rowIn)
df_a=pd.concat([df_a, rowH]).copy()
df_h=pd.concat([df_h, rowA]).copy()
    #df_p=df_a[df_a['Result']!= 'OwnGoal']
    #df_p.head()
#df_a['Result'].unique()

# %%
#rowH['Result']='Goal'
df_a.tail()
# Out:
#             X          Y        xG       Result                 Player  \
# 26  85.500000  30.600000  0.030170  BlockedShot              Bote Baku
# 27  82.400002  50.299999  0.055958  MissedShots           Antonio Nusa
# 28  80.500000  29.299999  0.019006    SavedShot  Christoph Baumgartner
# 29  80.400002  66.300003  0.029227  BlockedShot           Antonio Nusa
# 30  92.400002  39.700001  0.043030  MissedShots  Christoph Baumgartner
#
#    HomeAway
# 26        a
# 27        a
# 28        a
# 29        a
# 30        a

# %%
#df_a['Player'][15]

# %%
#df_h=df_h[df_h['Result']!= 'OwnGoal']
df_h['Result'].unique()
# Out:
# array(['BlockedShot', 'SavedShot', 'MissedShots', 'Goal'], dtype=object)

# %%
#df_h=df_h[df_h['Result']!= 'OwnGoal']
df_a['Result'].unique()
# Out:
# array(['MissedShots', 'BlockedShot', 'SavedShot'], dtype=object)

# %%
#ownGoalsH()
#df_a[df_a['Result']!= 'OwnGoal']
#df_h['Result'].unique()

# %%
#rowIn=df_h[df_h['Result']=='OwnGoal']
#rowIn

# %%
#pruebadf=pd.concat([df_a, rowIn])
#pruebadf['Result'].unique()

# %%
#df_h.drop(df_h[df_h['Result']=='OwnGoal'], axis=0)

# %%
#df_h=ownGoals(df_a, df_h)

# %%
df_a[df_a['Result']=='Goal']
# Out:
# Empty DataFrame
# Columns: [X, Y, xG, Result, Player, HomeAway]
# Index: []

# %%
len(df_a['Result'])
# Out:
# 12

# %% [markdown]
#  NOW WE NEED TO DOWNLOAD TWO PACKAGES MPLSOCCER AND HIGHLIGHT-TEXT

# %% [markdown]
# The documentation for mplsoccer is at https://mplsoccer.readthedocs.io/en/latest/gallery/index.html while that for highlight-text is at https://pypi.org/project/highlight-text/#:~:text=the%20examples%20below.-,Use,the%20figure%20in%20figure%20coordinates.

# %%
#pip install mplsoccer
#pip install highlight-text

# %%
from highlight_text import ax_text,fig_text
import mplsoccer

# %% [markdown]
# WE WILL CHANGE SOME OF THE BASIC PARAMETERS USING THE rcParams method OF MPL

# %%
background = '#D6DBD9'
text_color = 'black'
mpl.rcParams['xtick.color']=text_color
mpl.rcParams['ytick.color']=text_color
mpl.rcParams['text.color']=text_color
mpl.rcParams['font.family']='Calibri'
mpl.rcParams['legend.fontsize'] = 12

# %%
import  numpy as np

# %%
df_h['OGColor']=np.where(df_h['HomeAway']=='a', 'orange', 'red')
df_h.tail()
# Out:
#             X          Y        xG       Result          Player HomeAway  \
# 14  92.599998  62.700001  0.328854         Goal      Harry Kane        h
# 15  76.000000  40.299999  0.034764    SavedShot    Lennart Karl        h
# 16  80.000000  20.299999  0.017179  MissedShots  Joshua Kimmich        h
# 17  81.000000  25.100000  0.044700  BlockedShot    Lennart Karl        h
# 18  94.500000  32.099998  0.378717    SavedShot    Lennart Karl        h
#
#    OGColor
# 14     red
# 15     red
# 16     red
# 17     red
# 18     red

# %%
df_a['OGColor']=np.where(df_a['HomeAway']=='h', 'orange', 'red')
df_a.tail()
# Out:
#             X          Y        xG       Result                 Player  \
# 26  85.500000  30.600000  0.030170  BlockedShot              Bote Baku
# 27  82.400002  50.299999  0.055958  MissedShots           Antonio Nusa
# 28  80.500000  29.299999  0.019006    SavedShot  Christoph Baumgartner
# 29  80.400002  66.300003  0.029227  BlockedShot           Antonio Nusa
# 30  92.400002  39.700001  0.043030  MissedShots  Christoph Baumgartner
#
#    HomeAway OGColor
# 26        a     red
# 27        a     red
# 28        a     red
# 29        a     red
# 30        a     red

# %% [markdown]
# FINALLY WE USE THE OOPS API OF PYTHON TO PLOT OUR VIZ

# %%
# SETTING UP THE AXES
fig, ax = plt.subplots(figsize=(10,12))
ax.axis('off')
fig.set_facecolor(background)

#SETTING UP THE MPL AXIS FOR THE FIRST SEASON
pitch = mplsoccer.VerticalPitch(half=True,pitch_type='opta',line_zorder=3,pitch_color='grass')
ax_opta1 = fig.add_axes([0.02, 0.55, 1, 0.5])
ax_opta1.patch.set_facecolor(background)
pitch.draw(ax=ax_opta1)

#PLOTTING HTEAM
#df_fil = df_understat.loc[df_understat['HomeAway']=='h']
df_fil = df_h
df_hOG = df_fil[df_fil['HomeAway']=='a']

pitch.scatter(df_fil[df_fil['Result']!='Goal']['X'],df_fil[df_fil['Result']!='Goal']['Y'], 
              s=np.sqrt(df_fil[df_fil['Result']!='Goal']['xG'])*150, marker='o', alpha=0.6,
              edgecolor='black', facecolor='grey', ax=ax_opta1)

#NOW PLOTTING THE GOALS
pitch.scatter(df_fil[df_fil['Result']=='Goal']['X'],df_fil[df_fil['Result']=='Goal']['Y'], 
              s=np.sqrt(df_fil[df_fil['Result']=='Goal']['xG'])*150, marker='o', alpha=0.9,
              edgecolor='black', facecolor='red', ax=ax_opta1, label='GOL')
#OwnGoals
if len(df_hOG) >0:
    pitch.scatter(df_hOG[df_hOG['Result']=='Goal']['X'],df_hOG[df_hOG['Result']=='Goal']['Y'], 
              s=np.sqrt(df_hOG[df_hOG['Result']=='Goal']['xG'])*150, marker='x', alpha=0.9,
              edgecolor='black', facecolor='orange', ax=ax_opta1, label='AUTOGOL DEL RIVAL')


# ADDING THE LEGEND
ax_opta1.legend(loc='lower right').get_texts()[0].set_color("black")

ax_opta1.text(25,61,'GOLES : '+str(len(df_fil[df_fil['Result']=='Goal'])), weight='bold', size=15)
ax_opta1.text(25,64,f"xG : {round(sum(df_fil['xG']),2)}", weight='bold', size=15)
ax_opta1.text(25,58,'TIROS : '+str(len(df_fil)), weight='bold', size=15)
ax_opta1.text(85, 60, hteam, weight='bold', size=20)

# DOING THE SAME FOR THE 20-21 SEASON TOO
ax_opta2 = fig.add_axes([0.02, 0.01, 1, 0.5]) #l,b,w,h
ax_opta2.patch.set_facecolor(background)
pitch.draw(ax=ax_opta2)

#PLOTTING ATEAM
#df_fil = df_understat.loc[df_understat['HomeAway']=='a']
df_fil = df_a
df_hOG = df_fil[df_fil['HomeAway']=='h']


pitch.scatter(df_fil[df_fil['Result']!='Goal']['X'],df_fil[df_fil['Result']!='Goal']['Y'], 
              s=np.sqrt(df_fil[df_fil['Result']!='Goal']['xG'])*150, marker='o', alpha=0.6,
              edgecolor='black', facecolor='grey', ax=ax_opta2)

#NOW PLOTTING THE GOALS
pitch.scatter(df_fil[df_fil['Result']=='Goal']['X'],df_fil[df_fil['Result']=='Goal']['Y'], 
              s=np.sqrt(df_fil[df_fil['Result']=='Goal']['xG'])*150, marker='o', alpha=0.9,
              edgecolor='black', facecolor='red', ax=ax_opta2, label='GOL')

#OwnGoals
if len(df_hOG) >0:

    pitch.scatter(df_hOG[df_hOG['Result']=='Goal']['X'],df_hOG[df_hOG['Result']=='Goal']['Y'], 
              s=np.sqrt(df_hOG[df_hOG['Result']=='Goal']['xG'])*150, marker='x', alpha=0.9,
              edgecolor='black', facecolor='orange', ax=ax_opta2, label='AUTOGOL DEL RIVAL')

# ADDING THE LEGEND
ax_opta2.legend(loc='lower right').get_texts()[0].set_color("black")

ax_opta2.text(25,61,'GOLES : '+str(len(df_fil[df_fil['Result']=='Goal'])), weight='bold', size=15)
ax_opta2.text(25,64,f"xG : {round(sum(df_fil['xG']),2)}", weight='bold', size=15)
ax_opta2.text(25,58,'TIROS : '+str(len(df_fil)), weight='bold', size=15)
ax_opta2.text(85, 60, ateam, weight='bold', size=20)

# NOW PLOTTING THE SCATTERPLOT
#ax_scatter = fig.add_axes([0.52,0.57,0.4,0.35])
#ax_scatter.patch.set_facecolor(background)

# SETTING UP THE X AND Y OF THE SCATTERPLOT
#no_90s = 10
#df_fil = df_fbref[df_fbref['90s']>=no_90s]
#df_fil = df_fil[df_fil['Pos'].apply(lambda x: x in ['FW','MF,FW','FW,MF'])]

#x,y = (df_fil['xG']/df_fil['90s']).to_list(), (df_fil['Gls']/df_fil['90s']).to_list()

#ax_scatter.scatter(x,y,alpha=0.3,c='#EF8804')

# NOW FILTERING ERLING HAALAND'S DATA
#df_player = df_fil[df_fil['Player']=='Erling Haaland']
#ax_scatter.scatter(df_player['xG']/df_player['90s'], df_player['Gls']/df_player['90s'], c='blue')

# ADDING FINISHING TOUCHES TO THE SCATTERPLOT
#ax_scatter.grid(b = True, color ='grey',
#            linestyle ='-.', linewidth = 0.5,
#            alpha = 0.4)
#ax_scatter.set_xlabel('Expected Goals per 90', fontdict = {'fontsize':15, 'weight' : 'bold', 'color':text_color})
#ax_scatter.set_ylabel('Goals per 90', fontdict = dict(fontsize = 15, weight = 'bold',color=text_color))


#ADDING HAALAND'S IMAGE
#ax_player = fig.add_axes([0,0.43,0.25,0.45])
#ax_player.axis('off')
#im = plt.imread('haaland.png')
#ax_player.imshow(im)

# ADDING TITLES AND INFO
#fig_text(0.1,0.94,"<ERLING HAALAND> Y SU PÓLVORA",weight='heavy', size=25, highlight_textprops=[{'color':'blue'}])
#fig_text(0.25,0.85,'POSICIÓN: <DELANTERO>',weight='bold', size=20, highlight_textprops=[{'color':'#EF8804'}])
#fig_text(0.25,0.81,'EDAD: <21>',weight='bold', size=20, highlight_textprops=[{'color':'red'}])

# ADDING CLUB LOGO
#ax_team = fig.add_axes([0.27,0.55,0.15,0.15])
#ax_team.axis('off')
#im = plt.imread('bvb.png')
#ax_team.imshow(im)

# ADDING A FOOTER
fig_text(0.25,0.043,'Desarrollo: Enrique Adolfo López sobre código\n de Shreyas Khatri/@khatri_shreyas. Datos: Understat.com.')# Comparison with <forwards>'+
 #       ' with more than '+str(no_90s)+' 90s('+str(no_90s*90)+' minutes).',
  #      size=12, highlight_textprops=[{'color':'#EF8804'}], weight = 'bold')

plt.savefig(f'{hteam}{ateam}_viz.png',dpi=300,facecolor=background)

# %% [markdown]
# CONGRATULATIONS, YOU HAVE SUCCESSFULLY MADE YOURSELF THIS AMAZING VIZUALISATION
